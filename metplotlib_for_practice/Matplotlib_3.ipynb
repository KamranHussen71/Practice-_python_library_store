# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(10,60,(50))
print(x)
# Out:
# [28 36 50 56 14 15 35 58 29 42 58 16 42 34 57 30 32 33 23 50 29 53 10 19
#  24 52 20 41 51 45 31 15 41 41 13 43 28 36 28 59 25 18 52 12 14 44 15 28
#  20 15]

# %%
num = [28,36,50,56,14,15,35,58,29,42,58,16,42,34,57,30,32,33,23,50,29,53,10,19,
 24,52,20,41,51,45,31,15,41,41,13,43,28,36,28,59,25,18,52,12,14,44,15,28,20,15]
l = [10,20,30,40,50,60]
plt.hist(num,edgecolor="r",label="Python")

plt.title("Hellow")
plt.xlabel("Python")
plt.ylabel("NUMBER")

plt.axvline(40,color="g",label="line")

plt.legend()
plt.grid()
plt.show()
